# %%
import pandas as pd

# %%
data = pd.read_excel("nbyn.xlsx",index_col=0)

# %%
result = data[data>=0]

# %%
result.to_csv("nbyn.csv",encoding="utf_8_sig")

# %%
result
# Out:
#            北京        天津        河北        山西        内蒙        辽宁        吉林  \
# 北京   0.000000       NaN       NaN       NaN       NaN       NaN       NaN
# 天津   0.003479  0.000000       NaN       NaN       NaN       NaN       NaN
# 河北   0.068281  0.020555  0.000000  0.006408       NaN  0.008169       NaN
# 山西   0.174668  0.033498       NaN  0.000000       NaN  0.014025       NaN
# 内蒙   0.118710  0.172384  0.282428  0.462737  0.000000  0.046497       NaN
# 辽宁   0.036114  0.018585       NaN       NaN       NaN  0.000000       NaN
# 吉林   0.152226  0.042137  0.073335  0.092829  0.073158  0.171560  0.000000
# 黑龙江  0.204461  0.101503  0.095336       NaN  0.010538  0.104788  0.032401
# 上海   0.027601  0.004383       NaN       NaN       NaN  0.012451       NaN
# 江苏   0.025300  0.002794       NaN       NaN       NaN  0.007237       NaN
# 浙江   0.012614       NaN       NaN       NaN       NaN       NaN       NaN
# 安徽   0.006298  0.000888  0.027857       NaN       NaN  0.001817       NaN
# ...

# %%
print("hello world yuan")
# Out:
# hello world yuan
