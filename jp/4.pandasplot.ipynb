# %%
import pandas as pd
import numpy as np
import sklearn 
import matplotlib.pyplot as plt

# %%
data = {"a":list("123456"),"b":list("456789")}

# %%
df = pd.DataFrame(data)
df = df.astype(np.int32)

# %%
df.plot(alpha=0.8)
plt.plot(df.mean(axis=1),alpha=0.5,c='r')
plt.title("fuck")
plt.show()
