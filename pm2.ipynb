# %%
import openpyxl
import pandas as pd

# %%
wb = openpyxl.load_workbook("energy2.xlsx")

# %%
sh = wb.get_sheet_by_name("Shanghai2012")
# Out:
# d:\envs\crypt\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated function get_sheet_by_name (Use wb[sheetname]).
#   """Entry point for launching an IPython kernel.

# %%
sh.cell(20,20)
# Out:
# <Cell 'Shanghai2012'.T20>

# %%
sh['A1']
# Out:
# <Cell 'Shanghai2012'.A1>

# %%
cols = list(sh.columns)

# %%
sh.columns
# Out:
# <generator object Worksheet._cells_by_col at 0x000001DC8CF08EB8>

# %%
dfs = pd.read_excel("energy.xlsx",index_col=0,sheet_name=1)

# %%
dfs = pd.read_excel("energy.xlsx",index_col=0)

# %%
dfs.keys()
# Out:
# Index(['行业', 'Raw Coal', 'Cleaned Coal', 'Other Washed Coal', 'Briquettes',
#        'Coke', 'Coke Oven Gas', 'Other Gas', 'Other Coking Products',
#        'Crude Oil', 'Gasoline', 'Kerosene', 'Diesel Oil', 'Fuel Oil', 'LPG',
#        'Refinery Gas', 'Other Petroleum Products', 'Natural Gas', 'Heat',
#        'Electricity', 'Other Energy'],
#       dtype='object')

# %%
dfs.columns
# Out:
# Index(['行业', 'Raw Coal', 'Cleaned Coal', 'Other Washed Coal', 'Briquettes',
#        'Coke', 'Coke Oven Gas', 'Other Gas', 'Other Coking Products',
#        'Crude Oil', 'Gasoline', 'Kerosene', 'Diesel Oil', 'Fuel Oil', 'LPG',
#        'Refinery Gas', 'Other Petroleum Products', 'Natural Gas', 'Heat',
#        'Electricity', 'Other Energy'],
#       dtype='object')

# %%
dfs = pd.read_excel("energy2.xlsx")

# %%
dfs.shape
# Out:
# (59, 18)

# %%
def readdfs():
    dfs = pd.read_excel("energy2.xlsx",index_col=0,sheet_name=None)

# %%
dfs = pd.read_excel("energy2.xlsx",index_col=0,sheet_name=None)

# %%
dfs.keys()
# Out:
# dict_keys(['Shanghai2017', 'Yunnan2017', 'InnerMongolia2017', 'Beijing2017', 'Jilin2017', 'Sichuan2017', 'Tianjin2017', 'Ningxia2017', 'Anhui2017', 'Shandong2017', 'Shanxi2017', 'Guangdong2017', 'Guangxi2017', 'Xinjiang2017', 'Jiangsu2017', 'Jiangxi2017', 'Hebei2017', 'Henan2017', 'Zhejiang2017', 'Hainan2017', 'Hubei2017', 'Hunan2017', 'Gansu2017', 'Fujian2017', 'Guizhou2017', 'Liaoning2017', 'Chongqing2017', 'Shaanxi2017', 'Qinghai2017', 'Heilongjiang2017'])

# %%
df = dfs.get("Shanghai2017")

# %%
df.fillna(0,inplace=True)
df.head()
# Out:
# nan                                                          0  groupid  \
# NaN                                                          0      0.0
# 单位（10x 就是10的几次方                                              0      0.0
# Total Final Consumption                                    总消耗      0.0
# Farming, Forestry, Animal Husbandry, Fishery & ...  1农林牧渔业和水利业      1.0
# Coal Mining and Dressing                                2采煤与选矿      2.0
#
# nan                                                     原煤     洗精煤    其他洗煤  \
# NaN                                                     原煤     洗精煤    其他洗煤
# 单位（10x 就是10的几次方                                     104 tn  104 tn  104 tn
# Total Final Consumption                             478.87       0       0
# Farming, Forestry, Animal Husbandry, Fishery & ...    0.34       0       0
# Coal Mining and Dressing                                 0       0       0
#
# nan                                                     型煤      焦炭      焦炉煤气  \
# ...

# %%
cols = df.iloc[0]

# %%
cols[1] = "groupid"
# Out:
# d:\envs\crypt\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df.columns = cols

# %%
df
# Out:
# nan                                                                    0  \
# NaN                                                                    0
# 单位（10x 就是10的几次方                                                        0
# Total Final Consumption                                              总消耗
# Farming, Forestry, Animal Husbandry, Fishery & ...            1农林牧渔业和水利业
# Coal Mining and Dressing                                          2采煤与选矿
# Petroleum and Naturl Gas Extraction                           3石油、天然气开采业
# Ferrous Metals Mining and Dressing                             黑色金属开采和选矿
# Nonferrous Metals Mining and Dressing                          有色金属开采和选矿
# NaN                                                              4金属矿采选业
# Nonmetal Minerals Mining and Dressing                         非金属矿产开采与选矿
# Other Minerals Mining and Dressing                             其他矿产开采和选矿
# NaN                                                         5非金属矿和其他矿采选业
# ...

# %%
def process(df):
    df.fillna(0,inplace=True)
    df = df.groupby(by="groupid").sum()
    df = df.reset_index()
    df = df.reset_index(drop=True)
    df.drop(columns=[0],inplace=True)
    df.drop(index=[0],inplace=True)
    return df*f1*f2

# %%
df1 = df.groupby(by="groupid").sum()

# %%
df1 = df1.reset_index()

# %%
df1
# Out:
# nan  groupid                                               0          原煤  洗精煤  \
# 0        0.0                                             NaN         NaN  NaN
# 1        1.0                                      1农林牧渔业和水利业    0.340000  0.0
# 2        2.0                                          2采煤与选矿    0.000000  0.0
# 3        3.0                                      3石油、天然气开采业    0.000000  0.0
# 4        4.0                       黑色金属开采和选矿有色金属开采和选矿4金属矿采选业    0.000000  0.0
# 5        5.0                 非金属矿产开采与选矿其他矿产开采和选矿5非金属矿和其他矿采选业    0.000000  0.0
# 6        6.0                     食品加工食品生产饮料生产烟草加工6食品制造和烟草加工业   13.496478  0.0
# 7        7.0                                           7纺织工业   20.581986  0.0
# 8        8.0              服装和其他纤维产品皮革，毛皮，羽绒及相关产品8服装皮革羽绒及其制品业    7.884754  0.0
# 9        9.0  木材和竹子的采伐和运输采购产品木材加工，竹，藤，棕榈和稻草产品家具制造9木材加工和家具制造业    1.241381  0.0
# 10      10.0          造纸和纸制品印刷及记录介质复制文化，教育和体育文章10造纸印刷和文教体育用品   20.916423  0.0
# ...

# %%
df1.index = df1["groupid"]

# %%
df1
# Out:
# nan      groupid                                               0          原煤  \
# groupid
# 0.0          0.0                                             NaN         NaN
# 1.0          1.0                                      1农林牧渔业和水利业    0.340000
# 2.0          2.0                                          2采煤与选矿    0.000000
# 3.0          3.0                                      3石油、天然气开采业    0.000000
# 4.0          4.0                       黑色金属开采和选矿有色金属开采和选矿4金属矿采选业    0.000000
# 5.0          5.0                 非金属矿产开采与选矿其他矿产开采和选矿5非金属矿和其他矿采选业    0.000000
# 6.0          6.0                     食品加工食品生产饮料生产烟草加工6食品制造和烟草加工业   13.496478
# 7.0          7.0                                           7纺织工业   20.581986
# 8.0          8.0              服装和其他纤维产品皮革，毛皮，羽绒及相关产品8服装皮革羽绒及其制品业    7.884754
# 9.0          9.0  木材和竹子的采伐和运输采购产品木材加工，竹，藤，棕榈和稻草产品家具制造9木材加工和家具制造业    1.241381
# 10.0        10.0          造纸和纸制品印刷及记录介质复制文化，教育和体育文章10造纸印刷和文教体育用品   20.916423
# ...

# %%
df = df.reset_index(drop=True)

# %%
df.drop(columns=[0],inplace=True)

# %%
df.drop(columns=[0],inplace=True)
df.drop(index=[0],inplace=True)

# %%
df
# Out:
# nan          原煤  洗精煤  其他洗煤   型煤          焦炭       焦炉煤气       其他煤气     其他焦化产品  \
# 1      0.340000  0.0   0.0  0.0    0.000000   0.000000   0.000000   0.000000
# 2      0.000000  0.0   0.0  0.0    0.000000   0.000000   0.000000   0.000000
# 3      0.000000  0.0   0.0  0.0    0.000000   0.000000   0.000000   0.000000
# 4      0.000000  0.0   0.0  0.0    0.000000   0.000000   0.000000   0.000000
# 5      0.000000  0.0   0.0  0.0    0.000000   0.000000   0.000000   0.000000
# 6     13.496478  0.0   0.0  0.0    0.000000   0.000000   2.484519   0.000000
# 7     20.581986  0.0   0.0  0.0    0.000000   0.000000   0.000000   0.000000
# 8      7.884754  0.0   0.0  0.0    0.000000   0.000000   0.451731   0.000000
# 9      1.241381  0.0   0.0  0.0    0.052098   0.000000   0.225865   0.000000
# 10    20.916423  0.0   0.0  0.0    0.017366   0.000000   0.451731   0.000000
# 11     1.337744  0.0   0.0  0.0    0.000000   0.000000   0.000000   0.000000
# ...

# %%
factor = pd.read_excel("factor.xlsx")

# %%
factor = factor.T

# %%
factor
# Out:
#                    0         1         2         3         4          5   \
# 燃料类型               原煤       洗精煤      其他洗煤        型煤        焦炭       焦炉煤气
# 排放因子               10      1.65      1.65     0.625      0.14       0.14
# 单位            (g/ kg)   (g/ kg)   (g/ kg)   (g/ kg)   (g/ kg)    (g /m3)
# transfactor  10000000  10000000  10000000  10000000  10000000  100000000
#
#                     6         7         8         9         10        11  \
# 燃料类型              其他煤气    其他焦化产品        原油        汽油        煤油        柴油
# 排放因子              0.14      0.14      0.27      0.27       0.9      0.94
# 单位             (g /m3)   (g /kg)   (g /kg)   (g /kg)   (g /kg)   (g /kg)
# transfactor  100000000  10000000  10000000  10000000  10000000  10000000
#
#                    12         13        14
# 燃料类型              燃料油        天然气    其他石油产品
# 排放因子             1.34       0.17      1.34
# 单位            (g /kg)    (g /m3)   (g /kg)
# transfactor  10000000  100000000  10000000

# %%
factor.columns= factor.iloc[0]

# %%
factor
# Out:
# 燃料类型               原煤       洗精煤      其他洗煤        型煤        焦炭       焦炉煤气  \
# 燃料类型               原煤       洗精煤      其他洗煤        型煤        焦炭       焦炉煤气
# 排放因子               10      1.65      1.65     0.625      0.14       0.14
# 单位            (g/ kg)   (g/ kg)   (g/ kg)   (g/ kg)   (g/ kg)    (g /m3)
# transfactor  10000000  10000000  10000000  10000000  10000000  100000000
#
# 燃料类型              其他煤气    其他焦化产品        原油        汽油        煤油        柴油  \
# 燃料类型              其他煤气    其他焦化产品        原油        汽油        煤油        柴油
# 排放因子              0.14      0.14      0.27      0.27       0.9      0.94
# 单位             (g /m3)   (g /kg)   (g /kg)   (g /kg)   (g /kg)   (g /kg)
# transfactor  100000000  10000000  10000000  10000000  10000000  10000000
#
# 燃料类型              燃料油        天然气    其他石油产品
# 燃料类型              燃料油        天然气    其他石油产品
# 排放因子             1.34       0.17      1.34
# 单位            (g /kg)    (g /m3)   (g /kg)
# transfactor  10000000  100000000  10000000

# %%
factor.index
# Out:
# Index(['燃料类型', '排放因子', '单位', 'transfactor'], dtype='object')

# %%
ft = factor[df.columns].loc["排放因子",:]

# %%
ft2 = factor[df.columns].loc["transfactor",:]

# %%
def getfactor():
    factor = pd.read_excel("factor.xlsx")
    factor = factor.T
    factor.columns= factor.iloc[0]
    ft = factor[df.columns].loc["排放因子",:]
    ft2 = factor[df.columns].loc["transfactor",:]
    return ft,ft2

# %%
df.columns
# Out:
# Index(['原煤', '洗精煤', '其他洗煤', '型煤', '焦炭', '焦炉煤气', '其他煤气', '其他焦化产品', '原油', ' 汽油',
#        '煤油', '柴油', '燃料油', '其他石油产品', '天然气'],
#       dtype='object', name=nan)

# %%
factor.columns
# Out:
# Index(['原煤', '洗精煤', '其他洗煤', '型煤', '焦炭', '焦炉煤气', '其他煤气', '其他焦化产品', '原油', '汽油',
#        '煤油', '柴油', '燃料油', '天然气', '其他石油产品'],
#       dtype='object', name='燃料类型')

# %%
df
# Out:
# nan          原煤  洗精煤  其他洗煤   型煤          焦炭       焦炉煤气       其他煤气     其他焦化产品  \
# 1      0.340000  0.0   0.0  0.0    0.000000   0.000000   0.000000   0.000000
# 2      0.000000  0.0   0.0  0.0    0.000000   0.000000   0.000000   0.000000
# 3      0.000000  0.0   0.0  0.0    0.000000   0.000000   0.000000   0.000000
# 4      0.000000  0.0   0.0  0.0    0.000000   0.000000   0.000000   0.000000
# 5      0.000000  0.0   0.0  0.0    0.000000   0.000000   0.000000   0.000000
# 6     13.496478  0.0   0.0  0.0    0.000000   0.000000   2.484519   0.000000
# 7     20.581986  0.0   0.0  0.0    0.000000   0.000000   0.000000   0.000000
# 8      7.884754  0.0   0.0  0.0    0.000000   0.000000   0.451731   0.000000
# 9      1.241381  0.0   0.0  0.0    0.052098   0.000000   0.225865   0.000000
# 10    20.916423  0.0   0.0  0.0    0.017366   0.000000   0.451731   0.000000
# 11     1.337744  0.0   0.0  0.0    0.000000   0.000000   0.000000   0.000000
# ...

# %%
result = df*ft*ft2

# %%
result.to_csv("result_")
